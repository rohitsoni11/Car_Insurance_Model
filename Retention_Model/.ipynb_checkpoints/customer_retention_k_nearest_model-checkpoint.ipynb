# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-machine-learning/resources/bANLa) course resource._
#
# ---

# %% [markdown]
# ### Import required modules and load data file

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set_style("darkgrid")
# %matplotlib inline

retention_df = pd.read_csv('./data/retention/insurance_cust_retention.csv')

# %%
retention_df.head()
# Out:
#   Marital Status  AGE Gender  Car Value  Years of No Claims Bonus  \
# 0              M   45      F        500                         4
# 1              M   40      M       3000                         8
# 2              S   25      F       4000                         4
# 3              M   42      M       1800                         9
# 4              M   59      M       5000                         9
#
#    Annual Mileage Payment Method Acquisition Channel  \
# 0            6000        Monthly             Inbound
# 1            6000        Monthly             Inbound
# 2            4000        Monthly             Inbound
# 3           10000         Annual             Inbound
# 4            3000         Annual             Inbound
#
#    Years of Tenure with Current Provider  Price  \
# 0                                      4  289.4
# 1                                      4  170.4
# 2                                      4  466.1
# ...

# %%
retention_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20020 entries, 0 to 20019
# Data columns (total 14 columns):
# Marital Status                           20020 non-null object
# AGE                                      20020 non-null int64
# Gender                                   20020 non-null object
# Car Value                                20020 non-null int64
# Years of No Claims Bonus                 20020 non-null int64
# Annual Mileage                           20020 non-null int64
# Payment Method                           20020 non-null object
# Acquisition Channel                      20020 non-null object
# Years of Tenure with Current Provider    20020 non-null int64
# Price                                    20017 non-null float64
# Actual Change in Price vs last Year      20020 non-null object
# % Change in Price vs last Year           20020 non-null object
# Grouped Change in Price                  20020 non-null object
# ...

# %%
# marital_status = {'D':1, 'M':2, 'S':3, 'V':4, 'W':5}
# retention_df['Marital Status'] = [marital_status[item] for item in retention_df['Marital Status']]

# gender = {'C':1, 'F':2, 'M':3}
# retention_df['Gender'] = [gender[item] for item in retention_df['Gender']]

# payment_method = {'Annual':1, 'Monthly':2}
# retention_df['Payment Method'] = [payment_method[item] for item in retention_df['Payment Method']]

# acquisition_channel = {'Aggreg':1, 'Direct':2, 'Inbound': 3, 'Outbound': 4}
# retention_df['Acquisition Channel'] = [acquisition_channel[item] for item in retention_df['Acquisition Channel']]

# retention_df.head()

# %% [markdown]
# ## Data Cleanup

# %% [markdown]
# ### Find Duplicate Columns (if any):

# %%
# Get column names
column_names = retention_df.columns
# print(column_names)
# Get column data types
retention_df.dtypes

# Also check if the column is unique
for i in column_names:
  print('{} is duplicate: {}'.format(i, retention_df[i].is_unique))
# Out:
# Marital Status is duplicate: False
# AGE is duplicate: False
# Gender is duplicate: False
# Car Value is duplicate: False
# Years of No Claims Bonus is duplicate: False
# Annual Mileage is duplicate: False
# Payment Method is duplicate: False
# Acquisition Channel is duplicate: False
# Years of Tenure with Current Provider is duplicate: False
# Price is duplicate: False
# Actual Change in Price vs last Year is duplicate: False
# % Change in Price vs last Year is duplicate: False
# Grouped Change in Price is duplicate: False
# Renewed? is duplicate: False

# %% [markdown]
# ### Find Missing Values (if any):

# %%
retention_df.isnull().sum()
# Out:
# Marital Status                           0
# AGE                                      0
# Gender                                   0
# Car Value                                0
# Years of No Claims Bonus                 0
# Annual Mileage                           0
# Payment Method                           0
# Acquisition Channel                      0
# Years of Tenure with Current Provider    0
# Price                                    3
# Actual Change in Price vs last Year      0
# % Change in Price vs last Year           0
# Grouped Change in Price                  0
# Renewed?                                 0
# dtype: int64

# %% [markdown]
# ### Removing the Rows with Missing Values

# %%
retention_df = retention_df.dropna(how='any',axis=0)
retention_df.isnull().sum()
# Out:
# Marital Status                           0
# AGE                                      0
# Gender                                   0
# Car Value                                0
# Years of No Claims Bonus                 0
# Annual Mileage                           0
# Payment Method                           0
# Acquisition Channel                      0
# Years of Tenure with Current Provider    0
# Price                                    0
# Actual Change in Price vs last Year      0
# % Change in Price vs last Year           0
# Grouped Change in Price                  0
# Renewed?                                 0
# dtype: int64

# %% [markdown]
# ### Finding the Relevance of Features

# %%
# Plotting the impact of Marital Status on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Marital Status'][retention_df['Renewed?'] == 1], retention_df['Marital Status'][retention_df['Renewed?'] == 0]], 
         bins=90, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Marital Status');
plt.ylabel('Number of people');

# %%
# # Plotting the impact of Marital Status on Renewal
# sns.set(rc={'figure.figsize':(15,10)})
# plt.hist([retention_df['Renewed?'][retention_df['Marital Status'] == 'M'], retention_df['Renewed?'][retention_df['Marital Status'] == 'S'], retention_df['Renewed?'][retention_df['Marital Status'] == 'D']], 
#          bins=90, label=['M', 'S', 'D', 'W', 'V']);
# plt.legend(loc='upper right');
# plt.xlabel('Renewed');
# plt.ylabel('Number of people');

# %%
# Plotting the impact of Age on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['AGE'][retention_df['Renewed?'] == 1], retention_df['AGE'][retention_df['Renewed?'] == 0]], 
         bins=90, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('AGE');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Gender on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Gender'][retention_df['Renewed?'] == 1], retention_df['Gender'][retention_df['Renewed?'] == 0]], 
         bins=90, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Gender');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Car Value on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Car Value'][retention_df['Renewed?'] == 1], retention_df['Car Value'][retention_df['Renewed?'] == 0]], 
         bins=100, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Car Value');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Years of No Claims Bonus on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Years of No Claims Bonus'][retention_df['Renewed?'] == 1], retention_df['Years of No Claims Bonus'][retention_df['Renewed?'] == 0]], 
         bins=100, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Years Of No Claims Bonus');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Annual Mileage on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Annual Mileage'][retention_df['Renewed?'] == 1], retention_df['Annual Mileage'][retention_df['Renewed?'] == 0]], 
         bins=100, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Annual Mileage');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Payment Method on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Payment Method'][retention_df['Renewed?'] == 1], retention_df['Payment Method'][retention_df['Renewed?'] == 0]], 
         bins=10, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Payment Method');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Acquisition Channel on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Acquisition Channel'][retention_df['Renewed?'] == 1], retention_df['Acquisition Channel'][retention_df['Renewed?'] == 0]], 
         bins=10, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Acquisition Channel');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Years of Tenure with Current Provider on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Years of Tenure with Current Provider'][retention_df['Renewed?'] == 1], retention_df['Years of Tenure with Current Provider'][retention_df['Renewed?'] == 0]], 
         bins=10, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Years of Tenure with Current Provider');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Price on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Price'][retention_df['Renewed?'] == 1], retention_df['Price'][retention_df['Renewed?'] == 0]], 
         bins=10, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Price');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Actual Change in Price vs last Year on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Actual Change in Price vs last Year'][retention_df['Renewed?'] == 1], retention_df['Actual Change in Price vs last Year'][retention_df['Renewed?'] == 0]], 
         bins=100, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Actual Change in Price vs last Year');
plt.ylabel('Number of people');

# %%
# Plotting the impact of % Change in Price vs last Year on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['% Change in Price vs last Year'][retention_df['Renewed?'] == 1], retention_df['% Change in Price vs last Year'][retention_df['Renewed?'] == 0]], 
         bins=100, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('% Change in Price vs last Year');
plt.ylabel('Number of people');

# %%
# Plotting the impact of Grouped Change in Price on Renewal
sns.set(rc={'figure.figsize':(15,10)})
plt.hist([retention_df['Grouped Change in Price'][retention_df['Renewed?'] == 1], retention_df['Grouped Change in Price'][retention_df['Renewed?'] == 0]], 
         bins=10, label=['Renewed', 'Not Renewed']);
plt.legend(loc='upper right');
plt.xlabel('Grouped Change in Price');
plt.ylabel('Number of people');

# %%
# # plotting a scatter matrix
# from matplotlib import cm

# X = retention_df[['Marital Status', 'AGE', 'Gender', 'Car Value', 'Years of No Claims Bonus', 'Annual Mileage', 'Payment Method', 'Acquisition Channel', 'Years of Tenure with Current Provider', 'Price', 'Actual Change in Price vs last Year', '% Change in Price vs last Year', 'Grouped Change in Price']]
# y = retention_df['Renewed?']
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# cmap = cm.get_cmap('gnuplot')
# scatter = pd.scatter_matrix(X_train, c= y_train, marker = 'o', s=40, hist_kwds={'bins':25}, figsize=(15,15), cmap=cmap)

# %% [markdown]
# ### Examining the data

# %%
# retention_df = pd.concat([retention_df, pd.get_dummies(retention_df['Marital Status'], prefix='Marital Status')], axis=1)
# # retention_df[['Marital Status_D', 'Marital Status_M', 'Marital Status_S', 'Marital Status_V', 'Marital Status_W']]

# retention_df = pd.concat([retention_df, pd.get_dummies(retention_df['Gender'], prefix='Gender')], axis=1)
# # retention_df[['Gender_C', 'Gender_F', 'Gender_M']]

# retention_df = pd.concat([retention_df, pd.get_dummies(retention_df['Payment Method'], prefix='Payment Method')], axis=1)
# # retention_df[['Payment Method_Annual', 'Payment Method_Monthly']]


# retention_df = pd.concat([retention_df, pd.get_dummies(retention_df['Acquisition Channel'], prefix='Acquisition Channel')], axis=1)
# # retention_df[['Acquisition Channel_Aggreg', 'Acquisition Channel_Direct', 'Acquisition Channel_Inbound', 'Acquisition Channel_Outbound']]


# # retention_df = pd.get_dummies(retention_df)
# # retention_df.info()

# %%
retention_df['Actual Change in Price vs last Year'] = pd.to_numeric(retention_df['Actual Change in Price vs last Year'])
retention_df['% Change in Price vs last Year'] = retention_df['% Change in Price vs last Year'].str.rstrip('%').astype('float') / 100.0
retention_df['Grouped Change in Price'] = pd.to_numeric(retention_df['Grouped Change in Price'])

# %%
retention_df.head()
# Out:
#   Marital Status  AGE Gender  Car Value  Years of No Claims Bonus  \
# 0              M   45      F        500                         4
# 1              M   40      M       3000                         8
# 2              S   25      F       4000                         4
# 3              M   42      M       1800                         9
# 4              M   59      M       5000                         9
#
#    Annual Mileage Payment Method Acquisition Channel  \
# 0            6000        Monthly             Inbound
# 1            6000        Monthly             Inbound
# 2            4000        Monthly             Inbound
# 3           10000         Annual             Inbound
# 4            3000         Annual             Inbound
#
#    Years of Tenure with Current Provider  Price              ...               \
# 0                                      4  289.4              ...
# 1                                      4  170.4              ...
# ...

# %% [markdown]
# ### Create train-test split

# %%
from sklearn import preprocessing

# We use the most significant features to train the model
X = retention_df.drop(columns=['Marital Status', 'AGE', 'Gender', 'Annual Mileage', 'Payment Method', 'Acquisition Channel', 'Years of Tenure with Current Provider', 'Renewed?'])
# X = retention_df.drop(columns=['Marital Status', 'Gender', 'Payment Method', 'Acquisition Channel', 'Renewed?'])
y = retention_df['Renewed?']


# Normalize the data attributes
normalized_X = preprocessing.normalize(X)


# default is 75% / 25% train-test split
X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, random_state=0)

# %% [markdown]
# ### Create classifier object

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 120)

# %% [markdown]
# ### Train the classifier (fit the estimator) using the training data

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=120, p=2,
#            weights='uniform')

# %% [markdown]
# ### Estimate the accuracy of the classifier on future data, using the test data

# %%
knn.score(X_test, y_test)
# Out:
# 0.6225774225774225

# %% [markdown]
# ### Use the trained k-NN classifier model to classify new, previously unseen objects

# %%
# # Test the Prediction against 1 New Example
# retention_prediction = knn.predict([[50, 9000, 7999]])

# # retention_prediction[0]

# %% [markdown]
# ### How sensitive is k-NN classification accuracy to the choice of the 'k' parameter?

# %%
k_range = range(1,200)
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    scores.append(knn.score(X_test, y_test))
    
print(np.amax(scores))
plt.figure()
plt.xlabel('k')
plt.ylabel('accuracy')
plt.scatter(k_range, scores)
plt.xticks([0,50,100,110, 120, 130, 140, 150, 160, 170, 180, 190, 200]);
# Out:
# 0.6307692307692307

# %% [markdown]
# ### How sensitive is k-NN classification accuracy to the train/test split proportion?

# %%
t = [0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2]

knn = KNeighborsClassifier(n_neighbors = 5)

plt.figure()

for s in t:

    scores = []
    for i in range(1,1000):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1-s)
        knn.fit(X_train, y_train)
        scores.append(knn.score(X_test, y_test))
    plt.plot(s, np.mean(scores), 'bo')

plt.xlabel('Training set proportion (%)')
plt.ylabel('accuracy');
